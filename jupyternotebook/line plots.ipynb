# %% [markdown]
# # Import Libararies and make graphs

# %% [markdown]
# ## Load data set

# %%
import seaborn as sns
import matplotlib.pyplot as plt
i=sns.load_dataset("iris")
i
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Draw a line plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
i=sns.load_dataset("iris")

#draw a line plot
sns.lineplot(x="species", y="petal_width", data=i)
plt.show()

# %% [markdown]
# # Adding heading of the line plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
i=sns.load_dataset("iris")

#draw a line plot
sns.lineplot(x="species", y="petal_width", data=i)

#add title of plot
plt.title("Line graph for the specie and petal width of the data set iris")
plt.show()

# %% [markdown]
# # Adding limit to the x-axis or y-axis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
i=sns.load_dataset("iris")

#draw a line plot
sns.lineplot(x="species", y="petal_width", data=i)

#Adding limit to the y-axis because x-axis is not numeric
plt.ylim(1)

#add title of plot
plt.title("Line graph for the specie and petal width of the data set iris")
plt.show()

# %% [markdown]
# # Change the styles
# - Dark grid
# - White grid
# - White
# - ticks
# - Dark

# %%
import seaborn as sns
import matplotlib.pyplot as plt
i=sns.load_dataset("iris")

#draw a line plot
sns.lineplot(x="species", y="petal_width", data=i)

#Adding limit to the y-axis because x-axis is not numeric
plt.ylim(1)

#Adding the syle of graph
sns.set(style="dark")

#add title of plot
plt.title("Line graph for the specie and petal width of the data set iris")
plt.show()

# %% [markdown]
# # Size of polt

# %%
import seaborn as sns
import matplotlib.pyplot as plt
i=sns.load_dataset("iris")

# Size of figure
plt.figure(figsize= (9,6))

#draw a line plot
sns.lineplot(x="species", y="petal_width", data=i)



# #Adding limit to the y-axis because x-axis is not numeric
# #plt.ylim(1)

# #Adding the syle of graph
# sns.set(style="dark")

#add title of plot
plt.title("Line graph for the specie and petal width of the data set iris")
plt.show()
